# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Reading the table from the link provided and creating a dataframe

# %%
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
data = pd.read_html(url, header=0)
df = data[0]
df.head()
# Out:
#   Postcode           Borough      Neighborhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %% [markdown]
# #### Removing the rows that contain 'Not assigned' in the 'Borough' column

# %%
df = df.drop(df.index[df['Borough'] == 'Not assigned'])
# resetting the index values
df.reset_index(drop=True, inplace = True)
df.head()
# Out:
#   Postcode           Borough      Neighborhood
# 0      M3A        North York         Parkwoods
# 1      M4A        North York  Victoria Village
# 2      M5A  Downtown Toronto      Harbourfront
# 3      M6A        North York  Lawrence Heights
# 4      M6A        North York    Lawrence Manor

# %% [markdown]
# #### Renaming Neighborhoods that are "Not assigned"

# %%
# Renaming the neighborhoods that are "Not assigned" with Borough's name
df["Neighborhood"] = np.where((df.Neighborhood == 'Not assigned'), df.Borough,df.Neighborhood)

# %% [markdown]
# #### Grouping same postcodes into one line and reindexing

# %%
df = df.groupby(["Postcode", 'Borough'])['Neighborhood'].apply(lambda tags: ', '.join(tags)).to_frame().reset_index()

# %%
df.head(20)
# Out:
#    Postcode      Borough                                       Neighborhood
# 0       M1B  Scarborough                                     Rouge, Malvern
# 1       M1C  Scarborough             Highland Creek, Rouge Hill, Port Union
# 2       M1E  Scarborough                  Guildwood, Morningside, West Hill
# 3       M1G  Scarborough                                             Woburn
# 4       M1H  Scarborough                                          Cedarbrae
# 5       M1J  Scarborough                                Scarborough Village
# 6       M1K  Scarborough        East Birchmount Park, Ionview, Kennedy Park
# 7       M1L  Scarborough                    Clairlea, Golden Mile, Oakridge
# 8       M1M  Scarborough    Cliffcrest, Cliffside, Scarborough Village West
# 9       M1N  Scarborough                        Birch Cliff, Cliffside West
# 10      M1P  Scarborough  Dorset Park, Scarborough Town Centre, Wexford ...
# 11      M1R  Scarborough                                  Maryvale, Wexford
# 12      M1S  Scarborough                                          Agincourt
# 13      M1T  Scarborough            Clarks Corners, Sullivan, Tam O'Shanter
# 14      M1V  Scarborough  Agincourt North, L'Amoreaux East, Milliken, St...
# 15      M1W  Scarborough                                    L'Amoreaux West
# 16      M1X  Scarborough                                        Upper Rouge
# 17      M2H   North York                                  Hillcrest Village
# 18      M2J   North York                       Fairview, Henry Farm, Oriole
# 19      M2K   North York                                    Bayview Village

# %%
# shape of the dataframe
df.shape
# Out:
# (103, 3)

# %%
print('There are ' + str(df.shape[0]) + ' rows.')
# Out:
# There are 103 rows.

# %%
# getting coordinates from file provided
geospatial_data = pd.read_csv('Geospatial_Coordinates.csv')
geospatial_data.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
# renaming "Postal Code" to "Postcode"
geospatial_data = geospatial_data.rename(columns={geospatial_data.columns[0]: "Postcode" })

# %%
# merge the two dataframes using "Postcode column"
df = df.merge(geospatial_data, on = 'Postcode')

df.head()
# Out:
#   Postcode      Borough                            Neighborhood   Latitude  \
# 0      M1B  Scarborough                          Rouge, Malvern  43.806686
# 1      M1C  Scarborough  Highland Creek, Rouge Hill, Port Union  43.784535
# 2      M1E  Scarborough       Guildwood, Morningside, West Hill  43.763573
# 3      M1G  Scarborough                                  Woburn  43.770992
# 4      M1H  Scarborough                               Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %% [markdown]
# ## Exploring and Clustering

# %%
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Folium installed
# Libraries imported.

# %%
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# %%
# analizing dataframe
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(df['Borough'].unique()),
        df['Neighborhood'].shape[0]
    )
)
# Out:
# The dataframe has 11 boroughs and 103 neighborhoods.

# %%
address = 'Toronto, Ontario, Canada'

geolocator = Nominatim(user_agent="TO_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.653963, -79.387207.

# %% [markdown]
# ### Creating Map of Toronto

# %%
# create a map of Toronto that displays all the Neighborhoods and Borowughs
map_toronto = folium.Map(location = [latitude, longitude], zoom_start = 11)

#add red circles to represent Toronto's Neighbourhoods
for lat, long, bor, neigh in zip(df['Latitude'], df['Longitude'], 
                                 df['Borough'], df['Neighborhood']):
    label = '{}, {}'.format(neigh, bor)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, long],
        radius = 7, 
        popup = label,
        color = 'red',
        fill = True,
        fill_color = 'yellow',
        fill_opacity = 0.25,
        parse_html = False).add_to(map_toronto)
        
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Clustering the Boroughs

# %%
list_boroughs = df['Borough'].unique()
list_boroughs
# Out:
# array(['Scarborough', 'North York', 'East York', 'East Toronto',
#        'Central Toronto', 'Downtown Toronto', 'York', 'West Toronto',
#        'Mississauga', 'Etobicoke', "Queen's Park"], dtype=object)

# %%
def borough_loc(list_of_places):
    for place in list_of_places:
        address = (place + ", Ontario, Canada")
        geolocator = Nominatim(user_agent="TO_explorer")
        location = geolocator.geocode(address)
        latitude = location.latitude
        longitude = location.longitude
        print('{''}, {}, {},'.format(place,latitude,longitude))

# %%
borough_loc(list_boroughs)
# Out:
# Scarborough, 43.773077, -79.257774,
# North York, 43.7543263, -79.4491169663959,
# East York, 43.699971, -79.3325199626159,
# East Toronto, 43.626243, -79.396962,
# Central Toronto, 43.653963, -79.387207,
# Downtown Toronto, 43.6563221, -79.3809161,
# York, 44.0007518, -79.4372217,
# West Toronto, 43.653963, -79.387207,
# Mississauga, 43.590338, -79.645729,
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# C:\ProgramData\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1243         """Send a complete request to the server."""
# -> 1244         self._send_request(method, url, body, headers, encode_chunked)
#    1245
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1289             body = _encode(body, 'body')
# -> 1290         self.endheaders(body, encode_chunked=encode_chunked)
#    1291
#
# C:\ProgramData\Anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1238             raise CannotSendHeader()
# -> 1239         self._send_output(message_body, encode_chunked=encode_chunked)
#    1240
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# C:\ProgramData\Anaconda3\lib\http\client.py in send(self, data)
#     965             if self.auto_open:
# --> 966                 self.connect()
#     967             else:
#
# C:\ProgramData\Anaconda3\lib\http\client.py in connect(self)
#    1413             self.sock = self._context.wrap_socket(self.sock,
# -> 1414                                                   server_hostname=server_hostname)
#    1415
#
# C:\ProgramData\Anaconda3\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     422             context=self,
# --> 423             session=session
#     424         )
#
# C:\ProgramData\Anaconda3\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#     869                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 870                     self.do_handshake()
#     871             except (OSError, ValueError):
#
# C:\ProgramData\Anaconda3\lib\ssl.py in do_handshake(self, block)
#    1138                 self.settimeout(None)
# -> 1139             self._sslobj.do_handshake()
#    1140         finally:
#
# timeout: _ssl.c:1059: The handshake operation timed out
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\geopy\geocoders\base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     354         try:
# --> 355             page = requester(req, timeout=timeout, **kwargs)
#     356         except Exception as error:
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     524
# --> 525         response = self._open(req, data)
#     526
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in _open(self, req, data)
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in https_open(self, req)
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1318             except OSError as err: # timeout error
# -> 1319                 raise URLError(err)
#    1320             r = h.getresponse()
#
# URLError: <urlopen error _ssl.c:1059: The handshake operation timed out>
#
# During handling of the above exception, another exception occurred:
#
# GeocoderTimedOut                          Traceback (most recent call last)
# <ipython-input-19-18797e71f0a4> in <module>
# ----> 1 borough_loc(list_boroughs)
#
# <ipython-input-18-c83094f437e2> in borough_loc(list_of_places)
#       3         address = (place + ", Ontario, Canada")
#       4         geolocator = Nominatim(user_agent="TO_explorer")
# ----> 5         location = geolocator.geocode(address)
#       6         latitude = location.latitude
#       7         longitude = location.longitude
#
# C:\ProgramData\Anaconda3\lib\site-packages\geopy\geocoders\osm.py in geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded)
#     385
#     386         return self._parse_json(
# --> 387             self._call_geocoder(url, timeout=timeout), exactly_one
#     388         )
#     389
#
# C:\ProgramData\Anaconda3\lib\site-packages\geopy\geocoders\base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     376             elif isinstance(error, URLError):
#     377                 if "timed out" in message:
# --> 378                     raise GeocoderTimedOut('Service timed out')
#     379                 elif "unreachable" in message:
#     380                     raise GeocoderUnavailable('Service not available')
#
# GeocoderTimedOut: Service timed out

# %%
boroughs = ["Scarborough", 43.773077, -79.257774,
"North York", 43.7543263, -79.4491169663959,
"East York", 43.699971, -79.3325199626159,
"East Toronto", 43.626243, -79.396962,
"Central Toronto", 43.653963, -79.387207,
"Downtown Toronto", 43.6563221, -79.3809161,
"York", 44.0007518, -79.4372217,
"West Toronto", 43.653963, -79.387207,
"Mississauga", 43.590338, -79.645729,
"Etobicoke", 43.67145915, -79.5524920661167,
"Queen's Park", 43.6606092, -79.3905725,]

# %%
#creating borough dataframe
boroughs_df = pd.DataFrame(np.array(boroughs).reshape(11,3), columns = ["Borough","Latitude","Longitude"])
#changing strings to floats
boroughs_df["Latitude"] = pd.to_numeric(boroughs_df["Latitude"])
boroughs_df["Longitude"] = pd.to_numeric(boroughs_df["Longitude"])
boroughs_df.head(10)
# Out:
#             Borough   Latitude  Longitude
# 0       Scarborough  43.773077 -79.257774
# 1        North York  43.754326 -79.449117
# 2         East York  43.699971 -79.332520
# 3      East Toronto  43.626243 -79.396962
# 4   Central Toronto  43.653963 -79.387207
# 5  Downtown Toronto  43.656322 -79.380916
# 6              York  44.000752 -79.437222
# 7      West Toronto  43.653963 -79.387207
# 8       Mississauga  43.590338 -79.645729
# 9         Etobicoke  43.671459 -79.552492

# %% [markdown]
# ### Create a map of Toronto's Boroughs

# %%
# create a map of Toronto's Boroughs
map_toronto_boroughs = folium.Map(location = [43.653963, -79.387207], zoom_start = 10)

#add neighborhood markers to the Toronto map
for lat, long, bor in zip(boroughs_df['Latitude'], boroughs_df['Longitude'], 
                                 boroughs_df['Borough']):
    label = '{}'.format(bor)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, long],
        radius = 7, 
        popup = label,
        color = 'red',
        fill = True,
        fill_color = 'white',
        fill_opacity = 0.7,
        parse_html = False).add_to(map_toronto_boroughs)
        
map_toronto_boroughs
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import requests # library to handle requests
import random # library for random number generation

#!conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

#!conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Folium installed
# Libraries imported.

# %% [markdown]
# ## Using Foursquare

# %%
# Foursquare Login credentials
CLIENT_ID = '3HKW1CZU4NJOFN0W2VGXP0VG3E1FTVYDRIJPSXR1ZMUVDO4P' # your Foursquare ID
CLIENT_SECRET = '44KWZDKR2Q5YN3RECI2M0DIRJ25GWMYNCMXNPOIR002434DP' # your Foursquare Secret
VERSION = '20180604'

# %% [markdown]
# #### getting data for Queen's Park Neighborhood

# %%
queens_park_lat = boroughs_df.iloc[10,1]
queens_park_long = boroughs_df.iloc[10,2]

# %%
queens_park_df = df[df['Borough'] == "Queen's Park"].reset_index(drop = True)

# %%
neighborhood_latitude = queens_park_df.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = queens_park_df.loc[0, 'Longitude'] # neighborhood longitude value
neighborhood_name = queens_park_df.loc[0, 'Neighborhood'] # neighborhood name
print(neighborhood_name)
print('Coordinates of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Queen's Park
# Coordinates of Queen's Park are 43.6678556, -79.53224240000002.

# %% [markdown]
# #### Searching for all McDonalds Restaurants in the neighbourhood

# %%
search_query = 'McDonald'
radius = 500
print(search_query + ' .... OK!')
LIMIT = 100
# Out:
# McDonald .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION,  search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=3HKW1CZU4NJOFN0W2VGXP0VG3E1FTVYDRIJPSXR1ZMUVDO4P&client_secret=44KWZDKR2Q5YN3RECI2M0DIRJ25GWMYNCMXNPOIR002434DP&ll=43.653963,-79.387207&v=20180604&query=McDonald&radius=500&limit=100'

# %%
# storing results in results
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e12492347b43d0024204901'},
#  'response': {'venues': [{'id': '4ae879d4f964a520aaaf21e3',
#     'name': "McDonald's",
#     'location': {'address': '260 Yonge Street, Unit J-002, Urban Eatery',
#      'crossStreet': 'in Toronto Eaton Centre Urban Eatery',
#      'lat': 43.654699,
#      'lng': -79.381063,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654699,
#        'lng': -79.381063}],
#      'distance': 501,
#      'postalCode': 'M5B 2L9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['260 Yonge Street, Unit J-002, Urban Eatery (in Toronto Eaton Centre Urban Eatery)',
#       'Toronto ON M5B 2L9',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578256659',
#     'hasPerk': False},
#    {'id': '4c82f365dc018cfabeccd46c',
#     'name': "McDonald's",
#     'location': {'address': '109 McCaul Street',
#      'crossStreet': 'Grange Food Court',
#      'lat': 43.6537443145172,
#      'lng': -79.39091545774443,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6537443145172,
#        'lng': -79.39091545774443}],
#      'distance': 299,
#      'postalCode': 'M5T 3K5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['109 McCaul Street (Grange Food Court)',
#       'Toronto ON M5T 3K5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578256659',
#     'hasPerk': False},
#    {'id': '4b59f3bff964a52055a328e3',
#     'name': "McDonald's",
#     'location': {'address': '595 Bay St',
#      'crossStreet': 'btwn Edward St & Dundas St W',
#      'lat': 43.65625754381657,
#      'lng': -79.3832687171793,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65625754381657,
#        'lng': -79.3832687171793}],
#      'distance': 407,
#      'postalCode': 'M5G 1M5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['595 Bay St (btwn Edward St & Dundas St W)',
#       'Toronto ON M5G 1M5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578256659',
#     'hasPerk': False},
#    {'id': '4b213e29f964a520d93824e3',
#     'name': "McDonald's",
#     'location': {'address': '78 St. Patrick Street',
#      'lat': 43.65369665916784,
#      'lng': -79.39095350457508,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65369665916784,
#        'lng': -79.39095350457508}],
#      'distance': 303,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['78 St. Patrick Street', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578256659',
#     'hasPerk': False},
#    {'id': '4bace7b1f964a520d3173be3',
#     'name': "McDonald's",
#     'location': {'address': 'Richmond and Bay',
#      'crossStreet': 'on the PATH',
#      'lat': 43.651137148945416,
#      'lng': -79.38325614285806,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.651137148945416,
#        'lng': -79.38325614285806}],
#      'distance': 447,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Richmond and Bay (on the PATH)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578256659',
#     'hasPerk': False},
#    {'id': '4ce1a706df986ea880afed16',
#     'name': "McDonald's",
#     'location': {'address': '123 Queen St. West',
#      'lat': 43.65089,
#      'lng': -79.38375,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65089,
#        'lng': -79.38375}],
#      'distance': 441,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['123 Queen St. West', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578256659',
#     'hasPerk': False},
#    {'id': '525ea70f11d285cb8db4f221',
#     'name': 'McMurtry Gardens of Justice',
#     'location': {'address': '361 University Avenue',
#      'lat': 43.65313279999999,
#      'lng': -79.3873899,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65313279999999,
#        'lng': -79.3873899}],
#      'distance': 93,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['361 University Avenue', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d12d941735',
#       'name': 'Monument / Landmark',
#       'pluralName': 'Monuments / Landmarks',
#       'shortName': 'Landmark',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_monument_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578256659',
#     'hasPerk': False},
#    {'id': '51b03cd2498ecc9c45bc0d5b',
#     'name': 'McCaul & Dundas',
#     'location': {'address': 'Dundas St W',
#      'crossStreet': '& McCaul St',
#      'lat': 43.65437587151985,
#      'lng': -79.39044219968848,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65437587151985,
#        'lng': -79.39044219968848}],
#      'distance': 264,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Dundas St W (& McCaul St)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b4c',
#       'name': 'Intersection',
#       'pluralName': 'Intersections',
#       'shortName': 'Intersection',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578256659',
#     'hasPerk': False},
#    {'id': '5d9d323511e06d000734fa4c',
#     'name': 'MCO Downtown Toronto',
#     'location': {'address': '101 McCaul St',
#      'lat': 43.653425,
#      'lng': -79.39083,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.653425,
#        'lng': -79.39083}],
#      'distance': 297,
#      'postalCode': 'M5T 2X3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['101 McCaul St', 'Toronto ON M5T 2X3', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d178941735',
#       'name': "Dentist's Office",
#       'pluralName': "Dentist's Offices",
#       'shortName': "Dentist's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578256659',
#     'hasPerk': False},
#    {'id': '552db032498e660b6506230c',
#     'name': "Mo'Ramyun",
#     'location': {'address': '1 Baldwin St.',
#      'crossStreet': 'at Elm St.',
#      'lat': 43.65614757920083,
#      'lng': -79.39228230349781,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65614757920083,
#        'lng': -79.39228230349781}],
#      'distance': 475,
#      'postalCode': 'M5T 1L1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1 Baldwin St. (at Elm St.)',
#       'Toronto ON M5T 1L1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d113941735',
#       'name': 'Korean Restaurant',
#       'pluralName': 'Korean Restaurants',
#       'shortName': 'Korean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578256659',
#     'hasPerk': False},
#    {'id': '4b8e90ecf964a520122933e3',
#     'name': 'MCI Medical Clinic',
#     'location': {'address': '595 Bay St.',
#      'crossStreet': 'in Atrium on Bay',
#      'lat': 43.65613745484842,
#      'lng': -79.38345395206551,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65613745484842,
#        'lng': -79.38345395206551}],
#      'distance': 387,
#      'postalCode': 'M5G 2C2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['595 Bay St. (in Atrium on Bay)',
#       'Toronto ON M5G 2C2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'shortName': 'Medical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578256659',
#     'hasPerk': False},
#    {'id': '55a29fbd498ed70fbcd0a9a5',
#     'name': 'mcgarryTORONTO',
#     'location': {'lat': 43.65083279808508,
#      'lng': -79.38426783265596,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65083279808508,
#        'lng': -79.38426783265596}],
#      'distance': 421,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a3d',
#       'name': 'Advertising Agency',
#       'pluralName': 'Advertising Agencies',
#       'shortName': 'Advertising Agency',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578256659',
#     'hasPerk': False},
#    {'id': '4e31e22eb0fbb985a508b819',
#     'name': 'Sim & McBurney',
#     'location': {'address': '330 University Avenue',
#      'crossStreet': 'Queen & University',
#      'lat': 43.652212,
#      'lng': -79.388031,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.652212,
#        'lng': -79.388031}],
#      'distance': 205,
#      'postalCode': 'M5G 1R7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['330 University Avenue (Queen & University)',
#       'Toronto ON M5G 1R7',
#       'Canada']},
#     'categories': [{'id': '4d4b7105d754a06375d81259',
#       'name': 'Professional & Other Places',
#       'pluralName': 'Professional & Other Places',
#       'shortName': 'Professional',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578256659',
#     'hasPerk': False},
#    {'id': '4c73ed6e604a3704f77d7e49',
#     'name': 'McLean Budden Limited',
#     'location': {'address': '145 King Street West',
#      'lat': 43.651688610508984,
#      'lng': -79.38333311964438,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.651688610508984,
#        'lng': -79.38333311964438}],
#      'distance': 401,
#      'postalCode': 'M5H 1JB',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['145 King Street West',
#       'Toronto ON M5H 1JB',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578256659',
#     'hasPerk': False},
#    {'id': '4e53f419ae606f5737a59bbb',
#     'name': 'Pool At 53 McCaul',
#     'location': {'address': '53 McCaul',
#      'lat': 43.65202148538496,
#      'lng': -79.38975517371951,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65202148538496,
#        'lng': -79.38975517371951}],
#      'distance': 298,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['53 McCaul', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d15e941735',
#       'name': 'Pool',
#       'pluralName': 'Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578256659',
#     'hasPerk': False},
#    {'id': '4af8a8e5f964a520030f22e3',
#     'name': 'GoodLife Fitness Toronto McCaul and Queen',
#     'location': {'address': '21 McCaul St',
#      'crossStreet': 'at Queen St W',
#      'lat': 43.651148,
#      'lng': -79.389683,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.651148,
#        'lng': -79.389683}],
#      'distance': 371,
#      'postalCode': 'M5T 1V7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['21 McCaul St (at Queen St W)',
#       'Toronto ON M5T 1V7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578256659',
#     'hasPerk': False},
#    {'id': '57add958498ef8693a9f7c99',
#     'name': 'McCafé',
#     'location': {'address': '220 Yonge St',
#      'lat': 43.653427,
#      'lng': -79.380764,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.653427,
#        'lng': -79.380764}],
#      'distance': 522,
#      'postalCode': 'M5B 2H1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['220 Yonge St', 'Toronto ON M5B 2H1', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578256659',
#     'hasPerk': False},
#    {'id': '4ca243d8b0ff8cfad053ad5e',
#     'name': 'Dare@public Phones Dundat W@mccaul',
#     'location': {'address': '312',
#      'crossStreet': 'dundas st west',
#      'lat': 43.65447933129099,
#      'lng': -79.39139333447424,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65447933129099,
#        'lng': -79.39139333447424}],
#      'distance': 342,
#      'postalCode': 'M5T 1W2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['312 (dundas st west)',
#       'Toronto ON M5T 1W2',
#       'Canada']},
#     'categories': [],
#     'referralId': 'v-1578256659',
#     'hasPerk': False},
#    {'id': '5728c179498e95524604435c',
#     'name': 'McCracken Executive Search Inc',
#     'location': {'address': '2500-120 Adelaide St W',
#      'lat': 43.65,
#      'lng': -79.38316,
#      'labeledLatLngs': [{'label': 'display', 'lat': 43.65, 'lng': -79.38316}],
#      'distance': 548,
#      'postalCode': 'M5H 1T1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['2500-120 Adelaide St W',
#       'Toronto ON M5H 1T1',
#       'Canada']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b57',
#       'name': 'Recruiting Agency',
#       'pluralName': 'Recruiting Agencies',
#       'shortName': 'Recruiting Agency',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578256659',
#     'hasPerk': False},
#    {'id': '4cc85899a32bb1f74bbbada8',
#     'name': 'Mclean & kerr',
#     'location': {'address': '130 Adelaide St',
#      'crossStreet': 'York and Adelaide',
#      'lat': 43.64989355035037,
#      'lng': -79.38492762439303,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64989355035037,
#        'lng': -79.38492762439303}],
#      'distance': 488,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['130 Adelaide St (York and Adelaide)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [],
#     'referralId': 'v-1578256659',
#     'hasPerk': False},
#    {'id': '5114757fe4b0ec68c02e790d',
#     'name': '105 McCaul St',
#     'location': {'lat': 43.65371683269417,
#      'lng': -79.39083804887998,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65371683269417,
#        'lng': -79.39083804887998}],
#      'distance': 293,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578256659',
#     'hasPerk': False},
#    {'id': '4d4f9c0dbd6ff04d578adf0c',
#     'name': 'Mcarthur Properties Parking',
#     'location': {'address': 'Murray St',
#      'crossStreet': 'Elm st',
#      'lat': 43.65686940744255,
#      'lng': -79.39103047495841,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65686940744255,
#        'lng': -79.39103047495841}],
#      'distance': 446,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Murray St (Elm st)', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4c38df4de52ce0d596b336e1',
#       'name': 'Parking',
#       'pluralName': 'Parking',
#       'shortName': 'Parking',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578256659',
#     'hasPerk': False},
#    {'id': '4b85f094f964a5209c7a31e3',
#     'name': '105 mccaul st (The Train Station)',
#     'location': {'lat': 43.653886,
#      'lng': -79.391,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.653886,
#        'lng': -79.391}],
#      'distance': 305,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578256659',
#     'hasPerk': False},
#    {'id': '575252a8498e07a4d23c2459',
#     'name': 'Thompson Tooze McLean & Elkin',
#     'location': {'address': '1100-30 Saint Patrick St',
#      'lat': 43.651356,
#      'lng': -79.389008,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.651356,
#        'lng': -79.389008}],
#      'distance': 324,
#      'postalCode': 'M5T 3A3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1100-30 Saint Patrick St',
#       'Toronto ON M5T 3A3',
#       'Canada']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b3f',
#       'name': 'Lawyer',
#       'pluralName': 'Lawyers',
#       'shortName': 'Lawyer',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/lawschool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578256659',
#     'hasPerk': False},
#    {'id': '4e9f8be293ad16f0cda75c12',
#     'name': 'Riley McGivney Barristers And Solicitors',
#     'location': {'address': '439 University Ave',
#      'crossStreet': 'Dundas',
#      'lat': 43.656834,
#      'lng': -79.388313,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.656834,
#        'lng': -79.388313}],
#      'distance': 331,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['439 University Ave (Dundas)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578256659',
#     'hasPerk': False},
#    {'id': '51a78fd9498eeedec239cffa',
#     'name': 'OCAD U 49 McCaul',
#     'location': {'lat': 43.651822,
#      'lng': -79.390204,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.651822,
#        'lng': -79.390204}],
#      'distance': 339,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ae941735',
#       'name': 'University',
#       'pluralName': 'Universities',
#       'shortName': 'University',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578256659',
#     'hasPerk': False},
#    {'id': '525f90b8498e4b4bc399a937',
#     'name': 'TTC McCaul Loop',
#     'location': {'lat': 43.6519080041202,
#      'lng': -79.39060713705747,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6519080041202,
#        'lng': -79.39060713705747}],
#      'distance': 356,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fc931735',
#       'name': 'Light Rail Station',
#       'pluralName': 'Light Rail Stations',
#       'shortName': 'Light Rail',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/lightrail_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578256659',
#     'hasPerk': False},
#    {'id': '4fc27b8ee4b0cec9329626d0',
#     'name': 'Barbara McGivern',
#     'location': {'address': '176 John Street',
#      'crossStreet': 'Queen',
#      'lat': 43.650842,
#      'lng': -79.391819,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.650842,
#        'lng': -79.391819}],
#      'distance': 508,
#      'postalCode': 'M5T 1X5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['176 John Street (Queen)',
#       'Toronto ON M5T 1X5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578256659',
#     'hasPerk': False},
#    {'id': '505c5e73067d5277f873f7df',
#     'name': '49 McCaul Street',
#     'location': {'address': '49 McCaul Street',
#      'lat': 43.65178917967412,
#      'lng': -79.39053297042847,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65178917967412,
#        'lng': -79.39053297042847}],
#      'distance': 360,
#      'postalCode': 'M5T 1V7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['49 McCaul Street', 'Toronto ON M5T 1V7', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578256659',
#     'hasPerk': False},
#    {'id': '4d26143995e8f04df79f3f4d',
#     'name': 'Rosenswig McRae Thorpe',
#     'location': {'lat': 43.657410414349485,
#      'lng': -79.38483965243316,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.657410414349485,
#        'lng': -79.38483965243316}],
#      'distance': 428,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [],
#     'referralId': 'v-1578256659',
#     'hasPerk': False},
#    {'id': '5809e54c38fab0f7de5d78d7',
#     'name': 'Edward Jones - Financial Advisor: Chris McIntyre, CFP®|FMA',
#     'location': {'address': '150 York Street, Suite 912',
#      'lat': 43.64964923010267,
#      'lng': -79.38456212268449,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64964923010267,
#        'lng': -79.38456212268449}],
#      'distance': 525,
#      'postalCode': 'M5H 3S5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['150 York Street, Suite 912',
#       'Toronto ON M5H 3S5',
#       'Canada']},
#     'categories': [{'id': '5453de49498eade8af355881',
#       'name': 'Business Service',
#       'pluralName': 'Business Services',
#       'shortName': 'Business Services',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578256659',
#     'hasPerk': False},
#    {'id': '4c6dc74df323bfb769a11f99',
#     'name': 'Carolyn McAuley Hair Studio',
#     'location': {'address': '77 McCaul Street',
#      'lat': 43.6527071790916,
#      'lng': -79.39042020801706,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6527071790916,
#        'lng': -79.39042020801706}],
#      'distance': 294,
#      'postalCode': 'M5T 2W7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['77 McCaul Street', 'Toronto ON M5T 2W7', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'shortName': 'Salon / Barbershop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578256659',
#     'hasPerk': False},
#    {'id': '4d3db83a457cb60c1c87faa4',
#     'name': 'Robert R McEwen Atrium',
#     'location': {'lat': 43.658442410148595,
#      'lng': -79.39012331994117,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.658442410148595,
#        'lng': -79.39012331994117}],
#      'distance': 551,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578256659',
#     'hasPerk': False},
#    {'id': '4c06c1f09e1ab713cbe05243',
#     'name': 'The McMurtry-Scott Building',
#     'location': {'address': '720 Bay St.',
#      'crossStreet': 'Gerrard St. W.',
#      'lat': 43.65880590538596,
#      'lng': -79.385687304459,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65880590538596,
#        'lng': -79.385687304459}],
#      'distance': 552,
#      'postalCode': 'M7A 2S9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['720 Bay St. (Gerrard St. W.)',
#       'Toronto ON M7A 2S9',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d12d941735',
#       'name': 'Monument / Landmark',
#       'pluralName': 'Monuments / Landmarks',
#       'shortName': 'Landmark',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_monument_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578256659',
#     'hasPerk': False},
#    {'id': '51eea45f498ea1a2f307c690',
#     'name': 'Lloyd Burns McInnis LLP',
#     'location': {'address': '150 York Street',
#      'lat': 43.64961991853789,
#      'lng': -79.38419826562541,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64961991853789,
#        'lng': -79.38419826562541}],
#      'distance': 540,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['150 York Street', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578256659',
#     'hasPerk': False}]}}

# %% [markdown]
# #### Define information of interest and filter dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                          id        name  \
# 0  4ae879d4f964a520aaaf21e3  McDonald's
# 1  4c82f365dc018cfabeccd46c  McDonald's
# 2  4b59f3bff964a52055a328e3  McDonald's
# 3  4b213e29f964a520d93824e3  McDonald's
# 4  4bace7b1f964a520d3173be3  McDonald's
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...  v-1578256659    False
# 1  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...  v-1578256659    False
# 2  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...  v-1578256659    False
# 3  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...  v-1578256659    False
# 4  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...  v-1578256659    False
#
#                              location.address  \
# 0  260 Yonge Street, Unit J-002, Urban Eatery
# 1                           109 McCaul Street
# 2                                  595 Bay St
# 3                       78 St. Patrick Street
# 4                            Richmond and Bay
#
#                    location.crossStreet  location.lat  location.lng  \
# 0  in Toronto Eaton Centre Urban Eatery     43.654699    -79.381063
# 1                     Grange Food Court     43.653744    -79.390915
# 2          btwn Edward St & Dundas St W     43.656258    -79.383269
# 3                                   NaN     43.653697    -79.390954
# 4                           on the PATH     43.651137    -79.383256
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 43.654699, 'lng':...                501
# 1  [{'label': 'display', 'lat': 43.6537443145172,...                299
# 2  [{'label': 'display', 'lat': 43.65625754381657...                407
# 3  [{'label': 'display', 'lat': 43.65369665916784...                303
# 4  [{'label': 'display', 'lat': 43.65113714894541...                447
#
#   location.postalCode location.cc location.city location.state  \
# 0             M5B 2L9          CA       Toronto             ON
# 1             M5T 3K5          CA       Toronto             ON
# 2             M5G 1M5          CA       Toronto             ON
# 3                 NaN          CA       Toronto             ON
# 4                 NaN          CA       Toronto             ON
#
#   location.country                          location.formattedAddress
# 0           Canada  [260 Yonge Street, Unit J-002, Urban Eatery (i...
# 1           Canada  [109 McCaul Street (Grange Food Court), Toront...
# 2           Canada  [595 Bay St (btwn Edward St & Dundas St W), To...
# 3           Canada        [78 St. Patrick Street, Toronto ON, Canada]
# 4           Canada  [Richmond and Bay (on the PATH), Toronto ON, C...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                  name  \
# 0                                          McDonald's
# 1                                          McDonald's
# 2                                          McDonald's
# 3                                          McDonald's
# 4                                          McDonald's
# 5                                          McDonald's
# 6                         McMurtry Gardens of Justice
# 7                                     McCaul & Dundas
# 8                                MCO Downtown Toronto
# 9                                           Mo'Ramyun
# 10                                 MCI Medical Clinic
# 11                                     mcgarryTORONTO
# 12                                     Sim & McBurney
# 13                              McLean Budden Limited
# 14                                  Pool At 53 McCaul
# 15          GoodLife Fitness Toronto McCaul and Queen
# 16                                             McCafé
# 17                 Dare@public Phones Dundat W@mccaul
# 18                     McCracken Executive Search Inc
# 19                                      Mclean & kerr
# 20                                      105 McCaul St
# 21                        Mcarthur Properties Parking
# 22                  105 mccaul st (The Train Station)
# 23                      Thompson Tooze McLean & Elkin
# 24           Riley McGivney Barristers And Solicitors
# 25                                   OCAD U 49 McCaul
# 26                                    TTC McCaul Loop
# 27                                   Barbara McGivern
# 28                                   49 McCaul Street
# 29                             Rosenswig McRae Thorpe
# 30  Edward Jones - Financial Advisor: Chris McInty...
# 31                        Carolyn McAuley Hair Studio
# 32                             Robert R McEwen Atrium
# 33                        The McMurtry-Scott Building
# 34                            Lloyd Burns McInnis LLP
#
#                                   categories  \
# 0                       Fast Food Restaurant
# 1                       Fast Food Restaurant
# 2                       Fast Food Restaurant
# 3                       Fast Food Restaurant
# 4                       Fast Food Restaurant
# 5                       Fast Food Restaurant
# 6                        Monument / Landmark
# 7                               Intersection
# 8                           Dentist's Office
# 9                          Korean Restaurant
# 10                            Medical Center
# 11                        Advertising Agency
# 12               Professional & Other Places
# 13                                    Office
# 14                                      Pool
# 15                                       Gym
# 16                                      Café
# 17                                      None
# 18                         Recruiting Agency
# 19                                      None
# 20  Residential Building (Apartment / Condo)
# 21                                   Parking
# 22  Residential Building (Apartment / Condo)
# 23                                    Lawyer
# 24                                    Office
# 25                                University
# 26                        Light Rail Station
# 27                               Art Gallery
# 28                               Art Gallery
# 29                                      None
# 30                          Business Service
# 31                        Salon / Barbershop
# 32                                  Building
# 33                       Monument / Landmark
# 34                                    Office
#
#                                        address  \
# 0   260 Yonge Street, Unit J-002, Urban Eatery
# 1                            109 McCaul Street
# 2                                   595 Bay St
# 3                        78 St. Patrick Street
# 4                             Richmond and Bay
# 5                           123 Queen St. West
# 6                        361 University Avenue
# 7                                  Dundas St W
# 8                                101 McCaul St
# 9                                1 Baldwin St.
# 10                                 595 Bay St.
# 11                                         NaN
# 12                       330 University Avenue
# 13                        145 King Street West
# 14                                   53 McCaul
# 15                                21 McCaul St
# 16                                220 Yonge St
# 17                                         312
# 18                      2500-120 Adelaide St W
# 19                             130 Adelaide St
# 20                                         NaN
# 21                                   Murray St
# 22                                         NaN
# 23                    1100-30 Saint Patrick St
# 24                          439 University Ave
# 25                                         NaN
# 26                                         NaN
# 27                             176 John Street
# 28                            49 McCaul Street
# 29                                         NaN
# 30                  150 York Street, Suite 912
# 31                            77 McCaul Street
# 32                                         NaN
# 33                                 720 Bay St.
# 34                             150 York Street
#
#                              crossStreet        lat        lng  \
# 0   in Toronto Eaton Centre Urban Eatery  43.654699 -79.381063
# 1                      Grange Food Court  43.653744 -79.390915
# 2           btwn Edward St & Dundas St W  43.656258 -79.383269
# 3                                    NaN  43.653697 -79.390954
# 4                            on the PATH  43.651137 -79.383256
# 5                                    NaN  43.650890 -79.383750
# 6                                    NaN  43.653133 -79.387390
# 7                            & McCaul St  43.654376 -79.390442
# 8                                    NaN  43.653425 -79.390830
# 9                             at Elm St.  43.656148 -79.392282
# 10                      in Atrium on Bay  43.656137 -79.383454
# 11                                   NaN  43.650833 -79.384268
# 12                    Queen & University  43.652212 -79.388031
# 13                                   NaN  43.651689 -79.383333
# 14                                   NaN  43.652021 -79.389755
# 15                         at Queen St W  43.651148 -79.389683
# 16                                   NaN  43.653427 -79.380764
# 17                        dundas st west  43.654479 -79.391393
# 18                                   NaN  43.650000 -79.383160
# 19                     York and Adelaide  43.649894 -79.384928
# 20                                   NaN  43.653717 -79.390838
# 21                                Elm st  43.656869 -79.391030
# 22                                   NaN  43.653886 -79.391000
# 23                                   NaN  43.651356 -79.389008
# 24                                Dundas  43.656834 -79.388313
# 25                                   NaN  43.651822 -79.390204
# 26                                   NaN  43.651908 -79.390607
# 27                                 Queen  43.650842 -79.391819
# 28                                   NaN  43.651789 -79.390533
# 29                                   NaN  43.657410 -79.384840
# 30                                   NaN  43.649649 -79.384562
# 31                                   NaN  43.652707 -79.390420
# 32                                   NaN  43.658442 -79.390123
# 33                        Gerrard St. W.  43.658806 -79.385687
# 34                                   NaN  43.649620 -79.384198
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 43.654699, 'lng':...       501    M5B 2L9
# 1   [{'label': 'display', 'lat': 43.6537443145172,...       299    M5T 3K5
# 2   [{'label': 'display', 'lat': 43.65625754381657...       407    M5G 1M5
# 3   [{'label': 'display', 'lat': 43.65369665916784...       303        NaN
# 4   [{'label': 'display', 'lat': 43.65113714894541...       447        NaN
# 5   [{'label': 'display', 'lat': 43.65089, 'lng': ...       441        NaN
# 6   [{'label': 'display', 'lat': 43.65313279999999...        93        NaN
# 7   [{'label': 'display', 'lat': 43.65437587151985...       264        NaN
# 8   [{'label': 'display', 'lat': 43.653425, 'lng':...       297    M5T 2X3
# 9   [{'label': 'display', 'lat': 43.65614757920083...       475    M5T 1L1
# 10  [{'label': 'display', 'lat': 43.65613745484842...       387    M5G 2C2
# 11  [{'label': 'display', 'lat': 43.65083279808508...       421        NaN
# 12  [{'label': 'display', 'lat': 43.652212, 'lng':...       205    M5G 1R7
# 13  [{'label': 'display', 'lat': 43.65168861050898...       401    M5H 1JB
# 14  [{'label': 'display', 'lat': 43.65202148538496...       298        NaN
# 15  [{'label': 'display', 'lat': 43.651148, 'lng':...       371    M5T 1V7
# 16  [{'label': 'display', 'lat': 43.653427, 'lng':...       522    M5B 2H1
# 17  [{'label': 'display', 'lat': 43.65447933129099...       342    M5T 1W2
# 18  [{'label': 'display', 'lat': 43.65, 'lng': -79...       548    M5H 1T1
# 19  [{'label': 'display', 'lat': 43.64989355035037...       488        NaN
# 20  [{'label': 'display', 'lat': 43.65371683269417...       293        NaN
# 21  [{'label': 'display', 'lat': 43.65686940744255...       446        NaN
# 22  [{'label': 'display', 'lat': 43.653886, 'lng':...       305        NaN
# 23  [{'label': 'display', 'lat': 43.651356, 'lng':...       324    M5T 3A3
# 24  [{'label': 'display', 'lat': 43.656834, 'lng':...       331        NaN
# 25  [{'label': 'display', 'lat': 43.651822, 'lng':...       339        NaN
# 26  [{'label': 'display', 'lat': 43.6519080041202,...       356        NaN
# 27  [{'label': 'display', 'lat': 43.650842, 'lng':...       508    M5T 1X5
# 28  [{'label': 'display', 'lat': 43.65178917967412...       360    M5T 1V7
# 29  [{'label': 'display', 'lat': 43.65741041434948...       428        NaN
# 30  [{'label': 'display', 'lat': 43.64964923010267...       525    M5H 3S5
# 31  [{'label': 'display', 'lat': 43.6527071790916,...       294    M5T 2W7
# 32  [{'label': 'display', 'lat': 43.65844241014859...       551        NaN
# 33  [{'label': 'display', 'lat': 43.65880590538596...       552    M7A 2S9
# 34  [{'label': 'display', 'lat': 43.64961991853789...       540        NaN
#
#     cc     city state country  \
# 0   CA  Toronto    ON  Canada
# 1   CA  Toronto    ON  Canada
# 2   CA  Toronto    ON  Canada
# 3   CA  Toronto    ON  Canada
# 4   CA  Toronto    ON  Canada
# 5   CA  Toronto    ON  Canada
# 6   CA  Toronto    ON  Canada
# 7   CA  Toronto    ON  Canada
# 8   CA  Toronto    ON  Canada
# 9   CA  Toronto    ON  Canada
# 10  CA  Toronto    ON  Canada
# 11  CA      NaN   NaN  Canada
# 12  CA  Toronto    ON  Canada
# 13  CA  Toronto    ON  Canada
# 14  CA  Toronto    ON  Canada
# 15  CA  Toronto    ON  Canada
# 16  CA  Toronto    ON  Canada
# 17  CA  Toronto    ON  Canada
# 18  CA  Toronto    ON  Canada
# 19  CA  Toronto    ON  Canada
# 20  CA      NaN   NaN  Canada
# 21  CA  Toronto    ON  Canada
# 22  CA      NaN   NaN  Canada
# 23  CA  Toronto    ON  Canada
# 24  CA  Toronto    ON  Canada
# 25  CA  Toronto    ON  Canada
# 26  CA  Toronto    ON  Canada
# 27  CA  Toronto    ON  Canada
# 28  CA  Toronto    ON  Canada
# 29  CA      NaN   NaN  Canada
# 30  CA  Toronto    ON  Canada
# 31  CA  Toronto    ON  Canada
# 32  CA  Toronto    ON  Canada
# 33  CA  Toronto    ON  Canada
# 34  CA  Toronto    ON  Canada
#
#                                      formattedAddress  \
# 0   [260 Yonge Street, Unit J-002, Urban Eatery (i...
# 1   [109 McCaul Street (Grange Food Court), Toront...
# 2   [595 Bay St (btwn Edward St & Dundas St W), To...
# 3         [78 St. Patrick Street, Toronto ON, Canada]
# 4   [Richmond and Bay (on the PATH), Toronto ON, C...
# 5            [123 Queen St. West, Toronto ON, Canada]
# 6         [361 University Avenue, Toronto ON, Canada]
# 7     [Dundas St W (& McCaul St), Toronto ON, Canada]
# 8         [101 McCaul St, Toronto ON M5T 2X3, Canada]
# 9   [1 Baldwin St. (at Elm St.), Toronto ON M5T 1L...
# 10  [595 Bay St. (in Atrium on Bay), Toronto ON M5...
# 11                                           [Canada]
# 12  [330 University Avenue (Queen & University), T...
# 13  [145 King Street West, Toronto ON M5H 1JB, Can...
# 14                    [53 McCaul, Toronto ON, Canada]
# 15  [21 McCaul St (at Queen St W), Toronto ON M5T ...
# 16         [220 Yonge St, Toronto ON M5B 2H1, Canada]
# 17  [312 (dundas st west), Toronto ON M5T 1W2, Can...
# 18  [2500-120 Adelaide St W, Toronto ON M5H 1T1, C...
# 19  [130 Adelaide St (York and Adelaide), Toronto ...
# 20                                           [Canada]
# 21           [Murray St (Elm st), Toronto ON, Canada]
# 22                                           [Canada]
# 23  [1100-30 Saint Patrick St, Toronto ON M5T 3A3,...
# 24  [439 University Ave (Dundas), Toronto ON, Canada]
# 25                               [Toronto ON, Canada]
# 26                               [Toronto ON, Canada]
# 27  [176 John Street (Queen), Toronto ON M5T 1X5, ...
# 28     [49 McCaul Street, Toronto ON M5T 1V7, Canada]
# 29                                           [Canada]
# 30  [150 York Street, Suite 912, Toronto ON M5H 3S...
# 31     [77 McCaul Street, Toronto ON M5T 2W7, Canada]
# 32                               [Toronto ON, Canada]
# 33  [720 Bay St. (Gerrard St. W.), Toronto ON M7A ...
# 34              [150 York Street, Toronto ON, Canada]
#
#                           id
# 0   4ae879d4f964a520aaaf21e3
# 1   4c82f365dc018cfabeccd46c
# 2   4b59f3bff964a52055a328e3
# 3   4b213e29f964a520d93824e3
# 4   4bace7b1f964a520d3173be3
# 5   4ce1a706df986ea880afed16
# 6   525ea70f11d285cb8db4f221
# 7   51b03cd2498ecc9c45bc0d5b
# 8   5d9d323511e06d000734fa4c
# 9   552db032498e660b6506230c
# 10  4b8e90ecf964a520122933e3
# 11  55a29fbd498ed70fbcd0a9a5
# 12  4e31e22eb0fbb985a508b819
# 13  4c73ed6e604a3704f77d7e49
# 14  4e53f419ae606f5737a59bbb
# 15  4af8a8e5f964a520030f22e3
# 16  57add958498ef8693a9f7c99
# 17  4ca243d8b0ff8cfad053ad5e
# 18  5728c179498e95524604435c
# 19  4cc85899a32bb1f74bbbada8
# 20  5114757fe4b0ec68c02e790d
# 21  4d4f9c0dbd6ff04d578adf0c
# 22  4b85f094f964a5209c7a31e3
# 23  575252a8498e07a4d23c2459
# 24  4e9f8be293ad16f0cda75c12
# 25  51a78fd9498eeedec239cffa
# 26  525f90b8498e4b4bc399a937
# 27  4fc27b8ee4b0cec9329626d0
# 28  505c5e73067d5277f873f7df
# 29  4d26143995e8f04df79f3f4d
# 30  5809e54c38fab0f7de5d78d7
# 31  4c6dc74df323bfb769a11f99
# 32  4d3db83a457cb60c1c87faa4
# 33  4c06c1f09e1ab713cbe05243
# 34  51eea45f498ea1a2f307c690

# %%
dataframe_filtered = dataframe_filtered.drop(dataframe_filtered[dataframe_filtered["name"] != "McDonald's"].index)

# %% [markdown]
# ### Creating a Map of Queen's McDonalds Restaurants

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=16) # generate map 

# add the McDonald restaurants as blue circle markers
for lat, lng in zip(dataframe_filtered['lat'], dataframe_filtered['lng']):
    folium.features.CircleMarker(
        [lat, lng],
        radius=7,
        color='blue',        
        popup = "Mc Donalds",        
        fill = True,
        fill_color='blue',
        fill_opacity=0.3
    ).add_to(venues_map)

# display map of Queen's Park McDonalds Restaurants In Queen's Park
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
